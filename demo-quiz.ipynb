# %%
# Question

class Question:
    def __init__(self,text,choices,answer):
        self.text = text
        self.choices = choices
        self.answer = answer
    def checkAnswer(self, answer):
        return self.answer == answer

# q1  = Question("En iyi programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
# q2  = Question("En iyi popüler dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
# q3  = Question("En çok kazandıran programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")

# print(q1.checkAnswer("Python"))
# print(q2.checkAnswer("C#"))
# liste = [q1,q2,q3]

# Quiz

class Quiz:
    def __init__(self, questions):
        self.questions = questions
        self.score = 0
        self.questionIndex = 0

    def getQuestion(self):
        return quiz.questions[quiz.questionIndex]

    def displayQuestion(self):
        question = self.getQuestion()
        print(f"Soru {self.questionIndex + 1}: {question.text}")

        for q in question.choices:
            print("-"+ q)

        answer = input("Cevap: ")
        self.guess(answer)
        self.loadQuestion()

    def guess(self, answer):
        question = self.getQuestion()

        if question.checkAnswer(answer):
            self.score += 1
        self.questionIndex +=1

        self.displayQuestion()

    def loadQuestion(self):
        if len(self.questions) == self.questionIndex:
            self.showScore()
        else:
            self.displayProgress()
            self.displayQuestion()

    def showScore(self):
        print("Score: ", self.score)

    def displayProgress(self):
        totalQuestion = len(self.questions)
        questionNumber = self.questionIndex + 1

        if questionNumber > totalQuestion:
            print("Quiz bitti.")
        else:
            print(f"Question {questionNumber} of {totalQuestion}".center(100,'*'))

q1  = Question("En iyi programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
q2  = Question("En iyi popüler dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
q3  = Question("En çok kazandıran programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
q4  = Question("En çok sevilen programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")
q5  = Question("En kolay programlama dili hangisidir?", ["C#","Python","Javascript","Java"], "Python")

# print(q1.checkAnswer("Python"))
# print(q2.checkAnswer("C#"))

questions = [q1,q2,q3,q4,q5]

quiz = Quiz(questions)

quiz.loadQuestion()
# Out:
# ******************************************Question 1 of 5*******************************************
# Soru 1: En iyi programlama dili hangisidir?
# -C#
# -Python
# -Javascript
# -Java
# Soru 2: En iyi popüler dili hangisidir?
# -C#
# -Python
# -Javascript
# -Java
# Soru 3: En çok kazandıran programlama dili hangisidir?
# -C#
# -Python
# -Javascript
# -Java
# Soru 4: En çok sevilen programlama dili hangisidir?
# -C#
# -Python
# -Javascript
# -Java
# Soru 5: En kolay programlama dili hangisidir?
# -C#
# -Python
# -Javascript
# -Java
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [18], line 82
#      78 questions = [q1,q2,q3,q4,q5]
#      80 quiz = Quiz(questions)
# ---> 82 quiz.loadQuestion()
#
# Cell In [18], line 55, in Quiz.loadQuestion(self)
#      53 else:
#      54     self.displayProgress()
# ---> 55     self.displayQuestion()
#
# Cell In [18], line 38, in Quiz.displayQuestion(self)
#      35     print("-"+ q)
#      37 answer = input("Cevap: ")
# ---> 38 self.guess(answer)
#      39 self.loadQuestion()
#
# Cell In [18], line 48, in Quiz.guess(self, answer)
#      45     self.score += 1
#      46 self.questionIndex +=1
# ---> 48 self.displayQuestion()
#
# Cell In [18], line 38, in Quiz.displayQuestion(self)
#      35     print("-"+ q)
#      37 answer = input("Cevap: ")
# ---> 38 self.guess(answer)
#      39 self.loadQuestion()
#
# Cell In [18], line 48, in Quiz.guess(self, answer)
#      45     self.score += 1
#      46 self.questionIndex +=1
# ---> 48 self.displayQuestion()
#
#     [... skipping similar frames: Quiz.displayQuestion at line 38 (2 times), Quiz.guess at line 48 (2 times)]
#
# Cell In [18], line 38, in Quiz.displayQuestion(self)
#      35     print("-"+ q)
#      37 answer = input("Cevap: ")
# ---> 38 self.guess(answer)
#      39 self.loadQuestion()
#
# Cell In [18], line 48, in Quiz.guess(self, answer)
#      45     self.score += 1
#      46 self.questionIndex +=1
# ---> 48 self.displayQuestion()
#
# Cell In [18], line 31, in Quiz.displayQuestion(self)
#      30 def displayQuestion(self):
# ---> 31     question = self.getQuestion()
#      32     print(f"Soru {self.questionIndex + 1}: {question.text}")
#      34     for q in question.choices:
#
# Cell In [18], line 28, in Quiz.getQuestion(self)
#      27 def getQuestion(self):
# ---> 28     return quiz.questions[quiz.questionIndex]
#
# IndexError: list index out of range
