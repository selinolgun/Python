# %%
# 8 Bitlik Bir Sistem

for i in range(10):
    print(bin(i)[2:].zfill(8))
# Out:
# 00000000
# 00000001
# 00000010
# 00000011
# 00000100
# 00000101
# 00000110
# 00000111
# 00001000
# 00001001

# %%
for i in range(256):
    print(bin(i)[2:].zfill(8))
# Out:
# 00000000
# 00000001
# 00000010
# 00000011
# 00000100
# 00000101
# 00000110
# 00000111
# 00001000
# 00001001
# 00001010
# 00001011
# 00001100
# 00001101
# 00001110
# 00001111
# 00010000
# 00010001
# 00010010
# 00010011
# 00010100
# 00010101
# 00010110
# 00010111
# 00011000
# 00011001
# 00011010
# 00011011
# 00011100
# 00011101
# 00011110
# 00011111
# 00100000
# 00100001
# 00100010
# 00100011
# 00100100
# 00100101
# 00100110
# 00100111
# 00101000
# 00101001
# 00101010
# 00101011
# 00101100
# 00101101
# 00101110
# 00101111
# 00110000
# 00110001
# 00110010
# 00110011
# 00110100
# 00110101
# 00110110
# 00110111
# 00111000
# 00111001
# 00111010
# 00111011
# 00111100
# 00111101
# 00111110
# 00111111
# 01000000
# 01000001
# 01000010
# 01000011
# 01000100
# 01000101
# 01000110
# 01000111
# 01001000
# 01001001
# 01001010
# 01001011
# 01001100
# 01001101
# 01001110
# 01001111
# 01010000
# 01010001
# 01010010
# 01010011
# 01010100
# 01010101
# 01010110
# 01010111
# 01011000
# 01011001
# ...

# %%
for i in range(256):
    print(bin(i)[2:], i.bit_length(), sep="\t")
# Out:
# 0	0
# 1	1
# 10	2
# 11	2
# 100	3
# 101	3
# 110	3
# 111	3
# 1000	4
# 1001	4
# 1010	4
# 1011	4
# 1100	4
# 1101	4
# 1110	4
# 1111	4
# 10000	5
# 10001	5
# 10010	5
# 10011	5
# 10100	5
# 10101	5
# 10110	5
# 10111	5
# 11000	5
# 11001	5
# 11010	5
# 11011	5
# 11100	5
# 11101	5
# 11110	5
# 11111	5
# 100000	6
# 100001	6
# 100010	6
# 100011	6
# 100100	6
# 100101	6
# 100110	6
# 100111	6
# 101000	6
# 101001	6
# 101010	6
# 101011	6
# 101100	6
# 101101	6
# 101110	6
# 101111	6
# 110000	6
# 110001	6
# 110010	6
# 110011	6
# 110100	6
# 110101	6
# 110110	6
# 110111	6
# 111000	6
# 111001	6
# 111010	6
# 111011	6
# 111100	6
# 111101	6
# 111110	6
# 111111	6
# 1000000	7
# 1000001	7
# 1000010	7
# 1000011	7
# 1000100	7
# 1000101	7
# 1000110	7
# 1000111	7
# 1001000	7
# 1001001	7
# 1001010	7
# 1001011	7
# 1001100	7
# 1001101	7
# 1001110	7
# 1001111	7
# 1010000	7
# 1010001	7
# 1010010	7
# 1010011	7
# 1010100	7
# 1010101	7
# 1010110	7
# 1010111	7
# 1011000	7
# 1011001	7
# 1011010	7
# 1011011	7
# 1011100	7
# ...

# %%
# Karakterlerin Temsili
